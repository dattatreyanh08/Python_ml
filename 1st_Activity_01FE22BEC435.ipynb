# %% [markdown]
# <a href="https://colab.research.google.com/github/dattatreyanh08/Python_ml/blob/main/1st_Activity_01FE22BEC435.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path=('/content/drive/MyDrive/CSV.csv')
df=pd.read_csv(path)
df.describe
# Out:
# <bound method NDFrame.describe of        1  1.722778448  2.081018747
# 0      2     1.853528     2.605910
# 1      3     2.590116     1.920842
# 2      4     2.188698     2.146486
# 3      5     2.495787     3.233857
# 4      6     2.301726     2.573117
# ..   ...          ...          ...
# 164  166    -2.910219     2.990541
# 165  167    -3.509659     3.081623
# 166  168    -2.981200     2.639425
# 167  169    -2.931438     3.205302
# 168  170    -3.760526     2.393684
#
# [169 rows x 3 columns]>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/CSV.csv')
df.plot(kind='scatter', x ='2.081018747', y='1.722778448',marker='o',)
plt.title('COUSTER INTIAL PLOT')
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt


for i in range(1,8):
  x= np.array([int(random.randint(1,100))]).reshape((-1,1))

  y=int(random.randint(1,100))
  plt.plot(x,y)
  plt.grid()
  plt.scatter(x,y)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_excel('')

X = data[['X1', 'X2']]
y = data['Y']

X['bias'] = 1

X = X.to_numpy()
y = y.to_numpy()

theta = np.zeros(X.shape[1])

learning_rate = 0.01
num_iterations = 1000

for _ in range(num_iterations):

    predictions = np.dot(X, theta)

    errors = predictions - y

    gradients = np.dot(X.T, errors) / len(y)

    theta -= learning_rate * gradients

print("Learned Coefficients:", theta)

plt.scatter(X[:, 0], y, label='Actual data', color='blue')
plt.scatter(X[:, 0], predictions, label='Predicted data', color='red')
plt.plot(X[:, 0], predictions, label='Regression line', color='green')
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-d36eeb01854f> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 data = pd.read_excel("\My Drive\hii.csv"'')
#       6
#       7 X = data[['X1', 'X2']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_excel("/content/drive/MyDrive/DAT.xlsx")

X = data[['X1', 'X2']]
y = data['Y']

X['bias'] = 1

X = X.to_numpy()
y = y.to_numpy()

theta = np.zeros(X.shape[1])

learning_rate = 0.01
num_iterations = 1000

for _ in range(num_iterations):

    predictions = np.dot(X, theta)

    errors = predictions - y

    gradients = np.dot(X.T, errors) / len(y)

    theta -= learning_rate * gradients

print("Learned Coefficients:", theta)

plt.scatter(X[:, 0], y, label='Actual data', color='blue')
plt.scatter(X[:, 0], predictions, label='Predicted data', color='red')
plt.plot(X[:, 0], predictions, label='Regression line', color='green')
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()
# Out:
# Learned Coefficients: [ 0.48711634 -0.14115885  3.07950121]
